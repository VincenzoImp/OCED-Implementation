# %%
import pandas as pd
import json
from datetime import datetime

# %%
json_file = {
    'event' : {
        'event_0' : {
            'timestamp' : datetime,
            'type' : str,
            'attrs' : {}
        }
    },
    'object' : {
        'object_0' : {
            'type' : str,
            'attrs' : {}
        }
    },
    'object_object_rel' : {
        ('object_0', 'object_0') : {
            'type' : str
        }
    },
    'event_object_rel' : {
        ('event_0', 'object_0') : {
            'type' : str
        }
    }
}

# %%
event_df = pd.DataFrame({
    'event_id' : [],
    'timestamp' : [],
    'type' : []
})

event_attrs_df = pd.DataFrame({
    'event_id' : [],
    'name' : [],
    'value' : []
})

object_df = pd.DataFrame({
    'object_id' : [],
    'type' : []
})

object_attrs_df = pd.DataFrame({
    'object_id' : [],
    'name' : [],
    'value' : []
})

object_object_rel_df = pd.DataFrame({
    'object_id_from' : [],
    'object_id_to' : []
})

event_object_rel_df = pd.DataFrame({
    'event_id' : [],
    'object_id' : []
})

# %%
def dfs_to_json(event_df, event_attrs_df, object_df, object_attrs_df, object_object_rel_df, event_object_rel_df):
    return json_file

def json_to_dfs(json_file):
    return

# %%
class OCED:

    def __init__(self):

        json_file = {
            'event' : {},
            'object' : {},
            'object_object_rel' : {},
            'event_object_rel' : {}
        }

        event_df = pd.DataFrame({
            'event_id' : [],
            'timestamp' : [],
            'type' : []
        })

        event_attrs_df = pd.DataFrame({
            'event_id' : [],
            'name' : [],
            'value' : []
        })

        object_df = pd.DataFrame({
            'object_id' : [],
            'type' : []
        })

        object_attrs_df = pd.DataFrame({
            'object_id' : [],
            'name' : [],
            'value' : []
        })

        object_object_rel_df = pd.DataFrame({
            'object_id_from' : [],
            'object_id_to' : [],
            'type' : []
        })

        event_object_rel_df = pd.DataFrame({
            'event_id' : [],
            'object_id' : [],
            'type' : []
        })
        return
    
    def new_event(self, event_id, event_ts, event_type, event_attrs):
        return
    
    def del_event(self, event_id):
        return
    
    def new_object(self, object_id, object_type, object_attrs):
        return
    
    def del_object(self, object_id):
        return

    def new_obj_obj_rel(self, object_id_from, object_id_to, rel_type):
        return
    
    def del_obj_obj_rel(self, object_id_from, object_id_to):
        return
    
    def new_evt_obj_rel(self, event_id, object_id, rel_type):
        return
    
    def del_evt_obj_rel(self, event_id, object_id):
        return
    
    def get_json(self):
        return json_file
    
    def get_dfs(self):
        return event_df, event_attrs_df, object_df, object_attrs_df, object_object_rel_df, event_object_rel_df
